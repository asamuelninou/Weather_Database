# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1
# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_descrip = city_weather["weather"][0]["description"]     
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})      
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tilichiki
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | atagay
# Processing Record 5 of Set 1 | maltahohe
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | chute-aux-outardes
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | muros
# Processing Record 13 of Set 1 | bonavista
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | dedovichi
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | meulaboh
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | aketi
# Processing Record 23 of Set 1 | acajutla
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | visnes
# Processing Record 27 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | la tijera
# Processing Record 32 of Set 1 | college
# Processing Record 33 of Set 1 | hirna
# Processing Record 34 of Set 1 | leh
# Processing Record 35 of Set 1 | jinchang
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | doha
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | kuzino
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | atambua
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | da nang
# Processing Record 2 of Set 2 | muroto
# Processing Record 3 of Set 2 | luanda
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | oneida
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | torbay
# Processing Record 10 of Set 2 | serdobsk
# Processing Record 11 of Set 2 | sapouy
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | benguela
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | fare
# Processing Record 18 of Set 2 | ulladulla
# Processing Record 19 of Set 2 | kuala lipis
# Processing Record 20 of Set 2 | andrychow
# Processing Record 21 of Set 2 | port lincoln
# Processing Record 22 of Set 2 | okhotsk
# Processing Record 23 of Set 2 | pontian kecil
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | tuktoyaktuk
# Processing Record 27 of Set 2 | mezen
# Processing Record 28 of Set 2 | palmeirais
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | canela
# Processing Record 31 of Set 2 | pochutla
# Processing Record 32 of Set 2 | beringovskiy
# Processing Record 33 of Set 2 | coxim
# Processing Record 34 of Set 2 | liverpool
# Processing Record 35 of Set 2 | hayden
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | batagay
# Processing Record 38 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | tukrah
# Processing Record 44 of Set 2 | aguimes
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | lavrentiya
# Processing Record 47 of Set 2 | gijon
# Processing Record 48 of Set 2 | sungurlu
# Processing Record 49 of Set 2 | phan thiet
# Processing Record 50 of Set 2 | hopewell
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | najran
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | jicayan
# City not found. Skipping...
# Processing Record 9 of Set 3 | irawan
# Processing Record 10 of Set 3 | kloulklubed
# Processing Record 11 of Set 3 | dori
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | wick
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | aranos
# Processing Record 16 of Set 3 | tiznit
# Processing Record 17 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 18 of Set 3 | burley
# Processing Record 19 of Set 3 | safonovo
# Processing Record 20 of Set 3 | san jose
# Processing Record 21 of Set 3 | pleasant grove
# Processing Record 22 of Set 3 | ornskoldsvik
# Processing Record 23 of Set 3 | lucapa
# Processing Record 24 of Set 3 | vanimo
# Processing Record 25 of Set 3 | manado
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | coihaique
# Processing Record 28 of Set 3 | verkhnevilyuysk
# Processing Record 29 of Set 3 | the valley
# Processing Record 30 of Set 3 | kamenka
# Processing Record 31 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 3 | bac lieu
# Processing Record 33 of Set 3 | petatlan
# Processing Record 34 of Set 3 | grand-lahou
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | samarinda
# Processing Record 37 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | hambantota
# Processing Record 40 of Set 3 | merauke
# Processing Record 41 of Set 3 | ahuimanu
# Processing Record 42 of Set 3 | tura
# Processing Record 43 of Set 3 | kahului
# Processing Record 44 of Set 3 | aripuana
# Processing Record 45 of Set 3 | krivosheino
# Processing Record 46 of Set 3 | vallenar
# Processing Record 47 of Set 3 | isangel
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | morros
# Processing Record 50 of Set 3 | boda
# Processing Record 1 of Set 4 | cachira
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | monywa
# Processing Record 4 of Set 4 | itacare
# Processing Record 5 of Set 4 | talara
# Processing Record 6 of Set 4 | vao
# Processing Record 7 of Set 4 | fianga
# City not found. Skipping...
# Processing Record 8 of Set 4 | mount isa
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | morgan city
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | khandyga
# Processing Record 15 of Set 4 | colonial heights
# Processing Record 16 of Set 4 | hirara
# Processing Record 17 of Set 4 | ambilobe
# Processing Record 18 of Set 4 | nome
# Processing Record 19 of Set 4 | champasak
# Processing Record 20 of Set 4 | viedma
# Processing Record 21 of Set 4 | joinville
# Processing Record 22 of Set 4 | louis trichardt
# Processing Record 23 of Set 4 | tazovskiy
# Processing Record 24 of Set 4 | lensk
# Processing Record 25 of Set 4 | ust-kuyga
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | karratha
# Processing Record 28 of Set 4 | morogoro
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | bredasdorp
# Processing Record 31 of Set 4 | coahuayana
# Processing Record 32 of Set 4 | lagoa
# Processing Record 33 of Set 4 | tarata
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | general roca
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | poso
# Processing Record 40 of Set 4 | dawson
# Processing Record 41 of Set 4 | dulce nombre de culmi
# Processing Record 42 of Set 4 | hilo
# Processing Record 43 of Set 4 | kieta
# Processing Record 44 of Set 4 | amapa
# Processing Record 45 of Set 4 | souillac
# Processing Record 46 of Set 4 | wanparti
# Processing Record 47 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 4 | port-cartier
# Processing Record 49 of Set 4 | huanren
# Processing Record 50 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 5 | san cristobal
# Processing Record 2 of Set 5 | waingapu
# Processing Record 3 of Set 5 | cazones
# Processing Record 4 of Set 5 | kitimat
# Processing Record 5 of Set 5 | cidreira
# Processing Record 6 of Set 5 | ryotsu
# Processing Record 7 of Set 5 | berlevag
# Processing Record 8 of Set 5 | vila franca do campo
# Processing Record 9 of Set 5 | digby
# Processing Record 10 of Set 5 | leningradskiy
# Processing Record 11 of Set 5 | kamien pomorski
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | okha
# Processing Record 14 of Set 5 | capagao
# City not found. Skipping...
# Processing Record 15 of Set 5 | goldsboro
# Processing Record 16 of Set 5 | broken hill
# Processing Record 17 of Set 5 | kununurra
# Processing Record 18 of Set 5 | conde
# Processing Record 19 of Set 5 | shu
# Processing Record 20 of Set 5 | vocklabruck
# Processing Record 21 of Set 5 | hudiksvall
# Processing Record 22 of Set 5 | loandjili
# Processing Record 23 of Set 5 | beira
# Processing Record 24 of Set 5 | mweka
# Processing Record 25 of Set 5 | trairi
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | santo domingo
# Processing Record 28 of Set 5 | paita
# Processing Record 29 of Set 5 | makakilo city
# Processing Record 30 of Set 5 | udachnyy
# Processing Record 31 of Set 5 | paamiut
# Processing Record 32 of Set 5 | sao filipe
# Processing Record 33 of Set 5 | muli
# Processing Record 34 of Set 5 | zhigansk
# Processing Record 35 of Set 5 | hofn
# Processing Record 36 of Set 5 | sao gabriel da cachoeira
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | szendro
# Processing Record 40 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 41 of Set 5 | yulara
# Processing Record 42 of Set 5 | naryan-mar
# Processing Record 43 of Set 5 | am timan
# Processing Record 44 of Set 5 | tasiilaq
# Processing Record 45 of Set 5 | qeshm
# Processing Record 46 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 5 | kayerkan
# Processing Record 48 of Set 5 | tabuk
# Processing Record 49 of Set 5 | kochubey
# Processing Record 50 of Set 5 | bontang
# Processing Record 1 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | kanaya
# Processing Record 4 of Set 6 | sao jose da coroa grande
# Processing Record 5 of Set 6 | tondano
# Processing Record 6 of Set 6 | valparaiso
# Processing Record 7 of Set 6 | semirom
# Processing Record 8 of Set 6 | nouadhibou
# Processing Record 9 of Set 6 | lukiv
# Processing Record 10 of Set 6 | north bend
# Processing Record 11 of Set 6 | tanda
# Processing Record 12 of Set 6 | laguna
# Processing Record 13 of Set 6 | qaanaaq
# Processing Record 14 of Set 6 | unye
# City not found. Skipping...
# Processing Record 15 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | westerland
# Processing Record 17 of Set 6 | kyzyl
# Processing Record 18 of Set 6 | praya
# Processing Record 19 of Set 6 | hasaki
# Processing Record 20 of Set 6 | vytegra
# Processing Record 21 of Set 6 | sibolga
# Processing Record 22 of Set 6 | bellefontaine
# Processing Record 23 of Set 6 | port hardy
# Processing Record 24 of Set 6 | araouane
# Processing Record 25 of Set 6 | broome
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | menongue
# Processing Record 28 of Set 6 | upernavik
# Processing Record 29 of Set 6 | charters towers
# Processing Record 30 of Set 6 | malindi
# Processing Record 31 of Set 6 | anito
# Processing Record 32 of Set 6 | storm lake
# Processing Record 33 of Set 6 | kirakira
# Processing Record 34 of Set 6 | havre-saint-pierre
# Processing Record 35 of Set 6 | henties bay
# Processing Record 36 of Set 6 | richards bay
# Processing Record 37 of Set 6 | taoudenni
# Processing Record 38 of Set 6 | rabo de peixe
# Processing Record 39 of Set 6 | sarahan
# Processing Record 40 of Set 6 | manzanillo
# Processing Record 41 of Set 6 | korla
# Processing Record 42 of Set 6 | svetlogorsk
# Processing Record 43 of Set 6 | bulolo
# Processing Record 44 of Set 6 | margate
# Processing Record 45 of Set 6 | tashtyp
# Processing Record 46 of Set 6 | jaipur
# Processing Record 47 of Set 6 | yashkul
# Processing Record 48 of Set 6 | tainan
# Processing Record 49 of Set 6 | canico
# Processing Record 50 of Set 6 | zabol
# Processing Record 1 of Set 7 | carballo
# Processing Record 2 of Set 7 | mount gambier
# Processing Record 3 of Set 7 | san andres
# Processing Record 4 of Set 7 | stykkisholmur
# Processing Record 5 of Set 7 | palaia fokaia
# Processing Record 6 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 7 | lanzhou
# Processing Record 8 of Set 7 | amahai
# Processing Record 9 of Set 7 | isabela
# Processing Record 10 of Set 7 | vestmannaeyjar
# Processing Record 11 of Set 7 | suntar
# Processing Record 12 of Set 7 | ahipara
# Processing Record 13 of Set 7 | eureka
# Processing Record 14 of Set 7 | bertoua
# Processing Record 15 of Set 7 | alyangula
# Processing Record 16 of Set 7 | wanning
# Processing Record 17 of Set 7 | blonduos
# City not found. Skipping...
# Processing Record 18 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 19 of Set 7 | nelson bay
# Processing Record 20 of Set 7 | samarai
# Processing Record 21 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 7 | carikar
# City not found. Skipping...
# Processing Record 25 of Set 7 | kursenai
# Processing Record 26 of Set 7 | puerto lempira
# Processing Record 27 of Set 7 | paldiski
# Processing Record 28 of Set 7 | mubi
# Processing Record 29 of Set 7 | bengkulu
# Processing Record 30 of Set 7 | luderitz
# Processing Record 31 of Set 7 | aldan
# Processing Record 32 of Set 7 | merrill
# Processing Record 33 of Set 7 | katsuura
# Processing Record 34 of Set 7 | kudahuvadhoo
# Processing Record 35 of Set 7 | ponta do sol
# Processing Record 36 of Set 7 | ranot
# Processing Record 37 of Set 7 | los llanos de aridane
# Processing Record 38 of Set 7 | middelburg
# Processing Record 39 of Set 7 | novaya ladoga
# Processing Record 40 of Set 7 | alice springs
# Processing Record 41 of Set 7 | severo-kurilsk
# Processing Record 42 of Set 7 | geraldton
# Processing Record 43 of Set 7 | dzaoudzi
# Processing Record 44 of Set 7 | salair
# Processing Record 45 of Set 7 | bandarban
# Processing Record 46 of Set 7 | pandan
# Processing Record 47 of Set 7 | pingzhuang
# Processing Record 48 of Set 7 | manama
# Processing Record 49 of Set 7 | seymchan
# Processing Record 50 of Set 7 | loikaw
# Processing Record 1 of Set 8 | cumpas
# Processing Record 2 of Set 8 | vanavara
# Processing Record 3 of Set 8 | ixtapa
# Processing Record 4 of Set 8 | manggar
# Processing Record 5 of Set 8 | lebu
# Processing Record 6 of Set 8 | rocha
# Processing Record 7 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 8 | bismarck
# Processing Record 9 of Set 8 | mandera
# Processing Record 10 of Set 8 | sao felix do xingu
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | goderich
# Processing Record 13 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 8 | baijiantan
# Processing Record 15 of Set 8 | maragogi
# Processing Record 16 of Set 8 | moroni
# Processing Record 17 of Set 8 | celestun
# Processing Record 18 of Set 8 | luganville
# Processing Record 19 of Set 8 | newtownards
# Processing Record 20 of Set 8 | hobyo
# Processing Record 21 of Set 8 | serebryanyy bor
# Processing Record 22 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 23 of Set 8 | alice
# Processing Record 24 of Set 8 | gizo
# Processing Record 25 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 8 | mandalgovi
# Processing Record 27 of Set 8 | bilibino
# Processing Record 28 of Set 8 | sungai besar
# Processing Record 29 of Set 8 | selenginsk
# Processing Record 30 of Set 8 | fairview
# Processing Record 31 of Set 8 | panaba
# Processing Record 32 of Set 8 | promysla
# City not found. Skipping...
# Processing Record 33 of Set 8 | clarence town
# Processing Record 34 of Set 8 | potosi
# Processing Record 35 of Set 8 | marawi
# Processing Record 36 of Set 8 | lompoc
# Processing Record 37 of Set 8 | narsaq
# Processing Record 38 of Set 8 | harper
# Processing Record 39 of Set 8 | salisbury
# Processing Record 40 of Set 8 | flin flon
# Processing Record 41 of Set 8 | zhigalovo
# Processing Record 42 of Set 8 | kondoa
# Processing Record 43 of Set 8 | goba
# Processing Record 44 of Set 8 | moose factory
# Processing Record 45 of Set 8 | dobrichovice
# Processing Record 46 of Set 8 | cap malheureux
# Processing Record 47 of Set 8 | angoche
# Processing Record 48 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 8 | naze
# Processing Record 50 of Set 8 | omboue
# Processing Record 1 of Set 9 | marzuq
# Processing Record 2 of Set 9 | gympie
# Processing Record 3 of Set 9 | parkovyy
# Processing Record 4 of Set 9 | solyanka
# Processing Record 5 of Set 9 | ewa beach
# Processing Record 6 of Set 9 | mackay
# Processing Record 7 of Set 9 | brae
# Processing Record 8 of Set 9 | pimenteiras
# Processing Record 9 of Set 9 | corinto
# Processing Record 10 of Set 9 | iqaluit
# Processing Record 11 of Set 9 | ulaangom
# Processing Record 12 of Set 9 | petukhovo
# Processing Record 13 of Set 9 | honningsvag
# Processing Record 14 of Set 9 | san quintin
# Processing Record 15 of Set 9 | perth
# Processing Record 16 of Set 9 | verkhnyaya balkariya
# Processing Record 17 of Set 9 | birao
# Processing Record 18 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 9 | nemuro
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | flinders
# Processing Record 23 of Set 9 | constitucion
# Processing Record 24 of Set 9 | novoagansk
# Processing Record 25 of Set 9 | koumac
# Processing Record 26 of Set 9 | moerai
# Processing Record 27 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 9 | iquique
# Processing Record 29 of Set 9 | nanning
# Processing Record 30 of Set 9 | bonfim
# Processing Record 31 of Set 9 | iquitos
# Processing Record 32 of Set 9 | matola
# Processing Record 33 of Set 9 | bacolod
# Processing Record 34 of Set 9 | pedernales
# Processing Record 35 of Set 9 | road town
# Processing Record 36 of Set 9 | narrabri
# Processing Record 37 of Set 9 | kruisfontein
# Processing Record 38 of Set 9 | darnah
# Processing Record 39 of Set 9 | regeneracao
# Processing Record 40 of Set 9 | komsomolskiy
# Processing Record 41 of Set 9 | andenes
# Processing Record 42 of Set 9 | sao joao da barra
# Processing Record 43 of Set 9 | nalut
# Processing Record 44 of Set 9 | rudnichnyy
# Processing Record 45 of Set 9 | zemio
# Processing Record 46 of Set 9 | la palma
# Processing Record 47 of Set 9 | cibitoke
# Processing Record 48 of Set 9 | cambridge
# Processing Record 49 of Set 9 | kavieng
# Processing Record 50 of Set 9 | champerico
# Processing Record 1 of Set 10 | tougan
# Processing Record 2 of Set 10 | hokitika
# Processing Record 3 of Set 10 | bhadrak
# Processing Record 4 of Set 10 | ardmore
# Processing Record 5 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 10 | ketchikan
# Processing Record 7 of Set 10 | bocas del toro
# Processing Record 8 of Set 10 | pernik
# Processing Record 9 of Set 10 | santa cruz
# Processing Record 10 of Set 10 | urengoy
# Processing Record 11 of Set 10 | humboldt
# Processing Record 12 of Set 10 | knysna
# Processing Record 13 of Set 10 | staryy nadym
# Processing Record 14 of Set 10 | aksarayskiy
# Processing Record 15 of Set 10 | fomboni
# Processing Record 16 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 17 of Set 10 | avallon
# Processing Record 18 of Set 10 | acari
# Processing Record 19 of Set 10 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 20 of Set 10 | buchanan
# Processing Record 21 of Set 10 | cortes
# Processing Record 22 of Set 10 | mirandela
# Processing Record 23 of Set 10 | magadan
# Processing Record 24 of Set 10 | urbano santos
# Processing Record 25 of Set 10 | wajid
# Processing Record 26 of Set 10 | grand gaube
# Processing Record 27 of Set 10 | marsaxlokk
# Processing Record 28 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 10 | grindavik
# Processing Record 30 of Set 10 | starobaltachevo
# Processing Record 31 of Set 10 | sterling
# Processing Record 32 of Set 10 | thinadhoo
# Processing Record 33 of Set 10 | san ramon
# Processing Record 34 of Set 10 | palmer
# Processing Record 35 of Set 10 | port hedland
# Processing Record 36 of Set 10 | inuvik
# Processing Record 37 of Set 10 | rio gallegos
# Processing Record 38 of Set 10 | chardara
# Processing Record 39 of Set 10 | half moon bay
# Processing Record 40 of Set 10 | zhezkazgan
# Processing Record 41 of Set 10 | coquimbo
# Processing Record 42 of Set 10 | bilma
# Processing Record 43 of Set 10 | tanete
# Processing Record 44 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 45 of Set 10 | puerto lleras
# Processing Record 46 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 10 | belaya gora
# Processing Record 48 of Set 10 | byron bay
# Processing Record 49 of Set 10 | shieli
# Processing Record 50 of Set 10 | cedar city
# Processing Record 1 of Set 11 | bogatoye
# Processing Record 2 of Set 11 | grand island
# Processing Record 3 of Set 11 | sibu
# Processing Record 4 of Set 11 | gunjur
# Processing Record 5 of Set 11 | pimenta bueno
# Processing Record 6 of Set 11 | labuhan
# Processing Record 7 of Set 11 | paka
# Processing Record 8 of Set 11 | lasa
# Processing Record 9 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 11 | abalak
# Processing Record 11 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 11 | waitati
# Processing Record 13 of Set 11 | ballina
# Processing Record 14 of Set 11 | urumqi
# Processing Record 15 of Set 11 | cantaura
# Processing Record 16 of Set 11 | ruidoso
# Processing Record 17 of Set 11 | edd
# Processing Record 18 of Set 11 | waipawa
# Processing Record 19 of Set 11 | axim
# Processing Record 20 of Set 11 | nkowakowa
# Processing Record 21 of Set 11 | tres rios
# Processing Record 22 of Set 11 | whitehorse
# Processing Record 23 of Set 11 | cayenne
# Processing Record 24 of Set 11 | ibimirim
# Processing Record 25 of Set 11 | portland
# Processing Record 26 of Set 11 | porto santo
# Processing Record 27 of Set 11 | borogontsy
# Processing Record 28 of Set 11 | kaeo
# Processing Record 29 of Set 11 | arlit
# Processing Record 30 of Set 11 | mehamn
# Processing Record 31 of Set 11 | lata
# Processing Record 32 of Set 11 | denpasar
# Processing Record 33 of Set 11 | jamsa
# Processing Record 34 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 11 | vostok
# Processing Record 36 of Set 11 | caborca
# Processing Record 37 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 11 | lock haven
# Processing Record 39 of Set 11 | biloxi
# Processing Record 40 of Set 11 | sanandaj
# Processing Record 41 of Set 11 | ambon
# Processing Record 42 of Set 11 | sai buri
# Processing Record 43 of Set 11 | gravdal
# Processing Record 44 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 45 of Set 11 | sitka
# Processing Record 46 of Set 11 | comodoro rivadavia
# Processing Record 47 of Set 11 | eshowe
# Processing Record 48 of Set 11 | kurilsk
# Processing Record 49 of Set 11 | arani
# Processing Record 50 of Set 11 | beni mazar
# Processing Record 1 of Set 12 | ormara
# Processing Record 2 of Set 12 | san patricio
# Processing Record 3 of Set 12 | bijie
# Processing Record 4 of Set 12 | pasighat
# Processing Record 5 of Set 12 | charyshskoye
# Processing Record 6 of Set 12 | mogadishu
# Processing Record 7 of Set 12 | porto de moz
# Processing Record 8 of Set 12 | marquette
# Processing Record 9 of Set 12 | batagay-alyta
# Processing Record 10 of Set 12 | tabuleiro do norte
# Processing Record 11 of Set 12 | necochea
# Processing Record 12 of Set 12 | mecca
# Processing Record 13 of Set 12 | illela
# Processing Record 14 of Set 12 | sento se
# City not found. Skipping...
# Processing Record 15 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 12 | acapulco
# Processing Record 17 of Set 12 | develi
# Processing Record 18 of Set 12 | saldanha
# Processing Record 19 of Set 12 | kosino
# Processing Record 20 of Set 12 | harbour breton
# Processing Record 21 of Set 12 | yarada
# Processing Record 22 of Set 12 | ljubimec
# City not found. Skipping...
# Processing Record 23 of Set 12 | belyy yar
# Processing Record 24 of Set 12 | kulhudhuffushi
# Processing Record 25 of Set 12 | kysyl-syr
# Processing Record 26 of Set 12 | hanna
# Processing Record 27 of Set 12 | hervey bay
# Processing Record 28 of Set 12 | christchurch
# Processing Record 29 of Set 12 | deputatskiy
# Processing Record 30 of Set 12 | camopi
# Processing Record 31 of Set 12 | yerofey pavlovich
# Processing Record 32 of Set 12 | jagdalpur
# Processing Record 33 of Set 12 | bose
# Processing Record 34 of Set 12 | chapais
# Processing Record 35 of Set 12 | sobolevo
# Processing Record 36 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 12 | conakry
# Processing Record 38 of Set 12 | kasongo-lunda
# Processing Record 39 of Set 12 | malabo
# Processing Record 40 of Set 12 | along
# Processing Record 41 of Set 12 | columbia
# Processing Record 42 of Set 12 | roald
# Processing Record 43 of Set 12 | lahaina
# Processing Record 44 of Set 12 | saint anthony
# Processing Record 45 of Set 12 | sarangani
# Processing Record 46 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 12 | yabrud
# Processing Record 48 of Set 12 | hualmay
# Processing Record 49 of Set 12 | guozhen
# Processing Record 50 of Set 12 | ngama
# Processing Record 1 of Set 13 | puri
# Processing Record 2 of Set 13 | sefton
# Processing Record 3 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 13 | parabel
# Processing Record 5 of Set 13 | cherskiy
# Processing Record 6 of Set 13 | emba
# Processing Record 7 of Set 13 | boa vista
# Processing Record 8 of Set 13 | buckeye
# Processing Record 9 of Set 13 | anloga
# Processing Record 10 of Set 13 | kangaatsiaq
# Processing Record 11 of Set 13 | fort nelson
# Processing Record 12 of Set 13 | dingle
# Processing Record 13 of Set 13 | sangar
# Processing Record 14 of Set 13 | lusambo
# Processing Record 15 of Set 13 | lima
# Processing Record 16 of Set 13 | mizdah
# Processing Record 17 of Set 13 | micheweni
# Processing Record 18 of Set 13 | bagdarin
# Processing Record 19 of Set 13 | haines junction
# Processing Record 20 of Set 13 | rawlins
# Processing Record 21 of Set 13 | umm lajj
# Processing Record 22 of Set 13 | gat
# Processing Record 23 of Set 13 | robinson
# Processing Record 24 of Set 13 | arak
# Processing Record 25 of Set 13 | ostrovnoy
# Processing Record 26 of Set 13 | vila
# Processing Record 27 of Set 13 | izhmorskiy
# Processing Record 28 of Set 13 | padang
# Processing Record 29 of Set 13 | eyl
# Processing Record 30 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 31 of Set 13 | camacha
# Processing Record 32 of Set 13 | te anau
# Processing Record 33 of Set 13 | yar-sale
# Processing Record 34 of Set 13 | san felipe
# Processing Record 35 of Set 13 | san vicente
# Processing Record 36 of Set 13 | evensk
# Processing Record 37 of Set 13 | tuy hoa
# Processing Record 38 of Set 13 | gigmoto
# Processing Record 39 of Set 13 | yerbogachen
# Processing Record 40 of Set 13 | linxia
# Processing Record 41 of Set 13 | sola
# Processing Record 42 of Set 13 | krasnyy chikoy
# Processing Record 43 of Set 13 | haslett
# Processing Record 44 of Set 13 | srednekolymsk
# Processing Record 45 of Set 13 | negri
# Processing Record 46 of Set 13 | bowen
# Processing Record 47 of Set 13 | port blair
# Processing Record 48 of Set 13 | puerto quijarro
# Processing Record 49 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 13 | kerugoya
# Processing Record 1 of Set 14 | odessa
# Processing Record 2 of Set 14 | guerrero negro
# Processing Record 3 of Set 14 | hecun
# Processing Record 4 of Set 14 | codrington
# Processing Record 5 of Set 14 | afikpo
# Processing Record 6 of Set 14 | sakakah
# Processing Record 7 of Set 14 | usinsk
# Processing Record 8 of Set 14 | quatre cocos
# Processing Record 9 of Set 14 | fredonia
# Processing Record 10 of Set 14 | honiara
# Processing Record 11 of Set 14 | sirnak
# Processing Record 12 of Set 14 | akureyri
# Processing Record 13 of Set 14 | daru
# Processing Record 14 of Set 14 | quang ngai
# Processing Record 15 of Set 14 | khani
# Processing Record 16 of Set 14 | chicama
# Processing Record 17 of Set 14 | kralendijk
# Processing Record 18 of Set 14 | chambishi
# Processing Record 19 of Set 14 | puerto leguizamo
# Processing Record 20 of Set 14 | mbandaka
# Processing Record 21 of Set 14 | san policarpo
# Processing Record 22 of Set 14 | keti bandar
# Processing Record 23 of Set 14 | dezful
# Processing Record 24 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 14 | tocantinopolis
# City not found. Skipping...
# Processing Record 26 of Set 14 | san antonio
# Processing Record 27 of Set 14 | santa pola
# Processing Record 28 of Set 14 | jiangkou
# Processing Record 29 of Set 14 | kutum
# Processing Record 30 of Set 14 | mamallapuram
# Processing Record 31 of Set 14 | koroni
# Processing Record 32 of Set 14 | tsiroanomandidy
# Processing Record 33 of Set 14 | faya
# Processing Record 34 of Set 14 | kenai
# Processing Record 35 of Set 14 | anadyr
# Processing Record 36 of Set 14 | acarau
# Processing Record 37 of Set 14 | san rafael del sur
# Processing Record 38 of Set 14 | egvekinot
# Processing Record 39 of Set 14 | kousseri
# Processing Record 40 of Set 14 | irbit
# Processing Record 41 of Set 14 | san juan
# Processing Record 42 of Set 14 | barra do corda
# Processing Record 43 of Set 14 | bad camberg
# Processing Record 44 of Set 14 | llangefni
# Processing Record 45 of Set 14 | kadirli
# Processing Record 46 of Set 14 | amparafaravola
# Processing Record 47 of Set 14 | behbahan
# Processing Record 48 of Set 14 | husavik
# Processing Record 49 of Set 14 | dubbo
# Processing Record 50 of Set 14 | katobu
# Processing Record 1 of Set 15 | salinas
# Processing Record 2 of Set 15 | riyadh
# Processing Record 3 of Set 15 | opuwo
# Processing Record 4 of Set 15 | wum
# Processing Record 5 of Set 15 | houlung
# City not found. Skipping...
# Processing Record 6 of Set 15 | ust-koksa
# Processing Record 7 of Set 15 | marantao
# Processing Record 8 of Set 15 | belmonte
# Processing Record 9 of Set 15 | vestmanna
# Processing Record 10 of Set 15 | severobaykalsk
# Processing Record 11 of Set 15 | carutapera
# Processing Record 12 of Set 15 | mogadouro
# Processing Record 13 of Set 15 | jubayl
# City not found. Skipping...
# Processing Record 14 of Set 15 | caravelas
# Processing Record 15 of Set 15 | farafangana
# Processing Record 16 of Set 15 | seoul
# Processing Record 17 of Set 15 | les cayes
# Processing Record 18 of Set 15 | plouzane
# Processing Record 19 of Set 15 | tessalit
# Processing Record 20 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 15 | terrace bay
# Processing Record 22 of Set 15 | floro
# Processing Record 23 of Set 15 | methoni
# Processing Record 24 of Set 15 | churapcha
# Processing Record 25 of Set 15 | manjakandriana
# Processing Record 26 of Set 15 | mwingi
# Processing Record 27 of Set 15 | shingu
# Processing Record 28 of Set 15 | novyy urengoy
# Processing Record 29 of Set 15 | okitipupa
# Processing Record 30 of Set 15 | sherbrooke
# Processing Record 31 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 15 | tatarskaya pishlya
# Processing Record 33 of Set 15 | naliya
# Processing Record 34 of Set 15 | araceli
# Processing Record 35 of Set 15 | burnie
# Processing Record 36 of Set 15 | luba
# Processing Record 37 of Set 15 | kalmunai
# Processing Record 38 of Set 15 | omurtag
# Processing Record 39 of Set 15 | tevaitoa
# Processing Record 40 of Set 15 | aktas
# Processing Record 41 of Set 15 | svetlyy
# Processing Record 42 of Set 15 | brzeziny
# Processing Record 43 of Set 15 | mwense
# Processing Record 44 of Set 15 | susuman
# Processing Record 45 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 15 | kuito
# Processing Record 47 of Set 15 | ayan
# Processing Record 48 of Set 15 | catamarca
# Processing Record 49 of Set 15 | rawson
# Processing Record 50 of Set 15 | nadym
# Processing Record 1 of Set 16 | asfi
# Processing Record 2 of Set 16 | roma
# Processing Record 3 of Set 16 | sorland
# Processing Record 4 of Set 16 | beian
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 690

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Tilichiki  60.4667  166.1000    -25.46        98          69
# 1       Mar Del Plata -38.0023  -57.5575     74.82        64          20
# 2     Bambous Virieux -20.3428   57.7575     83.21        69          75
# 3              Atagay  55.1033   99.3875     29.79        84          89
# 4           Maltahohe -24.8333   16.9833     91.92        10           0
# 5           Busselton -33.6500  115.3333     69.46        80         100
# 6        Punta Arenas -53.1500  -70.9167     42.91        75         100
# 7              Hobart -42.8794  147.3294     57.06        57          40
# 8              Kodiak  57.7900 -152.4072     19.45        69           1
# 9  Chute-Aux-Outardes  49.1168  -68.3990     19.38        93         100
#
#    Wind Speed Country Current Description
# 0        4.74      RU       broken clouds
# 1       11.50      AR          few clouds
# 2        5.75      MU       broken clouds
# 3        5.68      RU     overcast clouds
# 4        8.30      NA           clear sky
# 5       14.09      AU     overcast clouds
# 6       10.36      CL     overcast clouds
# 7       20.71      AU    scattered clouds
# 8       34.27      US           clear sky
# 9        9.22      CA     overcast clouds

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Tilichiki  60.4667  166.1000    -25.46        98          69
# 1       Mar Del Plata -38.0023  -57.5575     74.82        64          20
# 2     Bambous Virieux -20.3428   57.7575     83.21        69          75
# 3              Atagay  55.1033   99.3875     29.79        84          89
# 4           Maltahohe -24.8333   16.9833     91.92        10           0
# 5           Busselton -33.6500  115.3333     69.46        80         100
# 6        Punta Arenas -53.1500  -70.9167     42.91        75         100
# 7              Hobart -42.8794  147.3294     57.06        57          40
# 8              Kodiak  57.7900 -152.4072     19.45        69           1
# 9  Chute-Aux-Outardes  49.1168  -68.3990     19.38        93         100
#
#    Wind Speed Country Current Description
# 0        4.74      RU       broken clouds
# 1       11.50      AR          few clouds
# 2        5.75      MU       broken clouds
# 3        5.68      RU     overcast clouds
# 4        8.30      NA           clear sky
# 5       14.09      AU     overcast clouds
# 6       10.36      CL     overcast clouds
# 7       20.71      AU    scattered clouds
# 8       34.27      US           clear sky
# 9        9.22      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tilichiki      RU  60.4667  166.1000    -25.46        98          69
# 1    Mar Del Plata      AR -38.0023  -57.5575     74.82        64          20
# 2  Bambous Virieux      MU -20.3428   57.7575     83.21        69          75
# 3           Atagay      RU  55.1033   99.3875     29.79        84          89
# 4        Maltahohe      NA -24.8333   16.9833     91.92        10           0
#
#    Wind Speed Current Description
# 0        4.74       broken clouds
# 1       11.50          few clouds
# 2        5.75       broken clouds
# 3        5.68     overcast clouds
# 4        8.30           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
